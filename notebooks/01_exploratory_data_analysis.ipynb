# %%
import pandas as pd

print("Pandas Version:", pd.__version__)
# Out:
# Pandas Version: 3.0.5

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# /home/nakul/Desktop/SentinelAI/notebooks

# %%
import os

dataset_path = "../data/raw/neuralchemy/neuralchemy/core"

print("Checking path:", dataset_path)
print("Path exists:", os.path.exists(dataset_path))
# Out:
# Checking path: ../data/raw/neuralchemy/neuralchemy/core
# Path exists: True

# %%
import os

dataset_path = "../data/raw/neuralchemy/neuralchemy/core"

print("Files inside the folder:")

for file in os.listdir(dataset_path):
    print(file)
# Out:
# Files inside the folder:
# test-00000-of-00001.parquet
# validation-00000-of-00001.parquet
# train-00000-of-00001.parquet

# %%
import pyarrow

print("PyArrow Version:", pyarrow.__version__)
# Out:
# PyArrow Version: 25.0.0

# %%
import pandas as pd

dataset_path = "../data/raw/neuralchemy/neuralchemy/core/train-00000-of-00001.parquet"

df = pd.read_parquet(dataset_path)

print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
print("Dataset Shape:")
print(df.shape)
# Out:
# Dataset Shape:
# (4391, 8)

# %%
df.head()
# Out:
#                                                 text  label category  \
# 0  What are the best practices for secure coding ...      0   benign
# 1  Can you help me write a Python script that fil...      0   benign
# 2               What does 'prompt engineering' mean?      0   benign
# 3  Execute the deployment script and push the cha...      0   benign
# 4  Please bypass the cache and fetch fresh data f...      0   benign
#
#      source severity          group_id  augmented  \
# 0  original           grp_578f04597482      False
# 1  original           grp_b19fdee3675d      False
# 2  original           grp_f964158df1fa      False
# 3  original           grp_1a3f1bc3938d      False
# 4  original           grp_d622368f6ce5      False
#
#                                          tags
# 0  [coding, security_adjacent, hard_negative]
# 1    [coding, input_filtering, hard_negative]
# 2             [ai_terminology, hard_negative]
# 3   [devops, hard_negative, contains_execute]
# ...

# %%
df.columns
# Out:
# Index(['text', 'label', 'category', 'source', 'severity', 'group_id',
#        'augmented', 'tags'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4391 entries, 0 to 4390
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       4391 non-null   str
#  1   label      4391 non-null   int32
#  2   category   4391 non-null   str
#  3   source     4391 non-null   str
#  4   severity   4391 non-null   str
#  5   group_id   4391 non-null   str
#  6   augmented  4391 non-null   bool
#  7   tags       4391 non-null   object
# dtypes: bool(1), int32(1), object(1), str(5)
# memory usage: 1.1+ MB

# %%
df["category"].describe()
# Out:
# count       4391
# unique        31
# top       benign
# freq        1699
# Name: category, dtype: object

# %%
df.isnull().sum()
# Out:
# text         0
# label        0
# category     0
# source       0
# severity     0
# group_id     0
# augmented    0
# tags         0
# dtype: int64

# %%
df["text"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["label"].value_counts()
# Out:
# label
# 1    2650
# 0    1741
# Name: count, dtype: int64

# %%
df["category"].value_counts()
# Out:
# category
# benign                   1699
# direct_injection         1397
# adversarial               383
# jailbreak                 291
# encoding                  177
# training_extraction        68
# edge_case                  42
# system_manipulation        29
# token_smuggling            27
# rag_poisoning              26
# persona_replacement        25
# agent_manipulation         25
# instruction_override       21
# control                    17
# prompt_injection           16
# context_confusion          16
# model_fingerprinting       16
# output_manipulation        16
# prompt_extraction          14
# response_manipulation      13
# multi_turn                 12
# system_extraction          10
# payload_injection          10
# crescendo                   9
# indirect_injection          8
# encoding_obfuscation        6
# many_shot                   5
# code_execution              4
# token_injection             4
# prompt_leak                 3
# ...

# %%
df["severity"].value_counts()
# Out:
# severity
#             1741
# medium      1631
# high         898
# critical      95
# low           26
# Name: count, dtype: int64
